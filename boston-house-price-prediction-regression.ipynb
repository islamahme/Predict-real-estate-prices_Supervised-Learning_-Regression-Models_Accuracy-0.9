# %% [markdown]
# <img src="house.jpg"/>

# %% [markdown]
# # House Price Prediction

# %% [markdown]
# ### Description
# Start here if...
# You have some experience with R or Python and machine learning basics. This is a perfect competition for data science students who have completed an online course in machine learning and are looking to expand their skill set before trying a featured competition.
#
# ### 💡Getting Started Notebook
# To get started quickly, feel free to take advantage of this starter notebook.
#
# ### Competition Description
#
#
# Ask a home buyer to describe their dream house, and they probably won't begin with the height of the basement ceiling or the proximity to an east-west railroad. But this playground competition's dataset proves that much more influences price negotiations than the number of bedrooms or a white-picket fence.
#
# With 79 explanatory variables describing (almost) every aspect of residential homes in Ames, Iowa, this competition challenges you to predict the final price of each home.
#
# ### Practice Skills
# Creative feature engineering
# Advanced regression techniques like random forest and gradient boosting
# Acknowledgments
# The Ames Housing dataset was compiled by Dean De Cock for use in data science education. It's an incredible alternative for data scientists looking for a modernized and expanded version of the often cited Boston Housing dataset.
#
# Photo by Tom Thain on Unsplash.
# Evaluation
# Goal
# It is your job to predict the sales price for each house. For each Id in the test set, you must predict the value of the SalePrice variable.
#
# ### Metric
# Submissions are evaluated on Root-Mean-Squared-Error (RMSE) between the logarithm of the predicted value and the logarithm of the observed sales price. (Taking logs means that errors in predicting expensive houses and cheap houses will affect the result equally.)
#
# Submission File Format
# The file should contain a header and have the following format:
# --------------------------------------
# Id,SalePrice
# 1461,169000.1
# 1462,187724.1233
# 1463,175221
# etc.
# ----------------------------------
# You can download an example submission file (sample_submission.csv) on the Data page.
#
# Tutorials
# Kaggle Learn
# Kaggle Learn offers hands-on courses for most data science topics. These short courses prepare you with the key ideas to build your own projects.
#
# The Machine Learning Course will give you everything you need to succeed in this competition and others like it.
#
# * Other R Tutorials
# * Fun with Real Estate Data
# * Use Rmarkdown to learn advanced regression techniques like random forests and XGBoost
# * XGBoost with Parameter Tuning
# * Implement LASSO regression to avoid multicollinearity
# * Includes linear regression, random forest, and XGBoost models as well
# * Ensemble Modeling: Stack Model Example
# * Use "ensembling" to combine the predictions of several models
# * Includes GBM (gradient boosting machine), XGBoost, ranger, and neural net using the caret package
# * A Clear Example of Overfitting
# * Learn about the dreaded consequences of overfitting data
# * Other Python Tutorials
# * Comprehensive Data Exploration with Python
# * Understand how variables are distributed and how they interact
# * Apply different transformations before training machine learning models
# * House Prices EDA
# * Learn to use visualization techniques to study missing data and distributions
# * Includes correlation heatmaps, pairplots, and t-SNE to help inform appropriate inputs to a linear model
# * A Study on Regression Applied to the Ames Dataset
# * Demonstrate effective tactics for feature engineering
# * Explore linear regression with different regularization methods including ridge, LASSO, and ElasticNet using scikit-learn
# * Regularized Linear Models
# * Build a basic linear model
# * Try more advanced algorithms including XGBoost and neural nets using Keras
# * Frequently Asked Questions
# ## What is a Getting Started competition?
# * Getting Started competitions were created by Kaggle data scientists for people who have little to no machine learning background. They are a great place to begin if you are new to data science or just finished a MOOC and want to get involved in Kaggle.
#
# * Getting Started competitions are a non-competitive way to get familiar with Kaggle’s platform, learn basic machine learning concepts, and start meeting people in the community. They have no cash prize and are on a rolling timeline.
#
# ## What’s the difference between a private and public leaderboard?
# * The Kaggle leaderboard has a public and private component to prevent participants from “overfitting” to the leaderboard. If your model is “overfit” to a dataset then it is not generalizable outside of the dataset you trained it on. This means that your model would have low accuracy on another sample of data taken from a similar dataset.
#
# ## Public Leaderboard
# * For all participants, the same 50% of predictions from the test set are assigned to the public leaderboard. The score you see on the public leaderboard reflects your model’s accuracy on this portion of the test set.
#
# ## Private Leaderboard
# * The other 50% of predictions from the test set are assigned to the private leaderboard. The private leaderboard is not visible to participants until the competition has concluded. At the end of a competition, we will reveal the private leaderboard so you can see your score on the other 50% of the test data. The scores on the private leaderboard are used to determine the competition winners. Getting Started competitions are run on a rolling timeline so the private leaderboard is never revealed.
#
# ## How do I create and manage a team?
# * When you accept the competition rules, a team will be created for you. You can invite others to your team, accept a merger with another team, and update basic information like team name by going to the More < Team page.
#
# * We've heard from many Kagglers that teaming up is the best way to learn new skills AND have fun. If you don't have a teammate already, consider asking if anyone wants to team up in the discussion forum.
#
# ## What are kernels?
# * Kaggle Kernels is a cloud computational environment that enables reproducible and collaborative analysis. Kernels supports scripts in R and Python, Jupyter Notebooks, and RMarkdown reports. Go to the Kernels tab to view all of the publicly shared code on this competition. For more on how to use Kernels to learn data science, visit the Read more about our decision to implement a rolling leaderboard on getting started competitions here.
#
# ## How do I contact Support?
# * Kaggle does not have a dedicated support team so you’ll typically find that you receive a response more quickly by asking your question in the appropriate forum. (For this competition, you’ll want to use the House Prices discussion forum).
#
# * Support is only able to help with issues that are being experienced by all participants. Before contacting support, please check the discussion forum for information on your problem. If you can’t find it, you can post your problem in the forum so a fellow participant or a Kaggle team member can provide help. The forums are full of useful information on the data, metric, and different approaches. We encourage you to use the forums often. If you share your knowledge, you'll find that others will share a lot in turn!
#
# ## If your problem persists or it seems to be affecting all participants then please contact us.
#
# ## Citation
# Anna Montoya, DataCanary. (2016). House Prices - Advanced Regression Techniques. Kaggle. https://kaggle.com/competitions/house-prices-advanced-regression-techniques

# %% [markdown]
# # 1- Getting The Data & Import Liberies

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import norm
from sklearn.preprocessing import StandardScaler
from scipy import stats
import warnings
warnings.filterwarnings( 'ignore')
# %matplotlib inline

from catboost import CatBoostRegressor
from lightgbm import LGBMRegressor
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.exceptions import ConvergenceWarning
from sklearn.linear_model import LinearRegression, Ridge, Lasso, ElasticNet
from sklearn.neighbors import KNeighborsRegressor
from sklearn.svm import SVR
from sklearn.tree import DecisionTreeRegressor
from xgboost import XGBRegressor
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import mean_squared_error
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split, cross_val_score,GridSearchCV


test_df = pd.read_csv(r"C:\Users\islam\OneDrive\Desktop\Work File\Machine Learning\Supervised ML_Regression\boston-house-price-prediction-regression\house-prices-advanced-regression-techniques\test.csv")
train_df = pd.read_csv(r"C:\Users\islam\OneDrive\Desktop\Work File\Machine Learning\Supervised ML_Regression\boston-house-price-prediction-regression\house-prices-advanced-regression-techniques\train.csv")
train_df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %% [markdown]
# # 2- Exploratory Data Analysis - EDA

# %%
# What  is The information about The datasets Like features (columns) and Size of data and data types
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %% [markdown]
# ### Result :
#    * 1- we have 1460 entries the our data is big And Also total 81 columns
#    * 2- dtypes: float64(3), int64(35), object(43) It is clear that the data has more 43 object type features than the others
#    * 3- memory usage: 924.0+ KB  It is clear that the data has more 43 object type features than the others
#    * 4- Obviously, some data features contain null values !!

# %%
# What is The Descriptive Statistic about the datasets And Displys by charts (Histgram or Distplot , Boxplot , scatterplot ) 
train_df.describe()
#train_df['SalePrice'].describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  ...  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000  ...
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726  ...
# std       1.112799    30.202904     20.645407   181.066207   456.098091  ...
# ...

# %% [markdown]
# For the Ground Floor Area column, we see that the average ground floor area is 1,510.55 square feet, but there is a large variation in values with the minimum ranging from 334 square feet to the maximum of 4,476 square feet.

# %%
sns.distplot(train_df['SalePrice'])
#skewness & Kurtosis
print('Skewness :%f'% train_df['SalePrice'].skew())
print('Kurtosis :%f'% train_df['SalePrice'].kurt())
# Out:
# Skewness :1.882876
# Kurtosis :6.536282

# %%
sns.violinplot(data=train_df, x="SalePrice", inner_kws=dict(box_width=15, whis_width=2, color=".8"))
# Out:
# <Axes: xlabel='SalePrice'>

# %% [markdown]
# 1- The value of the **Skewness** (torsion) coefficient of 1.882876 indicates that the data is skewed to the right. This means that there are more high values in the data than low values.
#
# 2-The value of the **Kurtosis** (hyperbole) coefficient of 6.536282 indicates that the data is more hyperbolic than the normal distribution. This means that there are more outliers in the data than in the normal distribution.

# %%
train_df.hist(figsize=(20,15))
plt.show()

# %%
sns.set()
cols=['SalePrice','OverallQual','GrLivArea','GarageCars','TotalBsmtSF','FullBath','YearBuilt']
sns.pairplot(train_df[cols],size=2.5)
plt.show()

# %%
# columns with data type "object" (Qualitative Data)
train_df.describe(include=['O'])
# Out:
#        MSZoning Street Alley LotShape LandContour Utilities LotConfig  \
# count      1460   1460    91     1460        1460      1460      1460
# unique        5      2     2        4           4         2         5
# top          RL   Pave  Grvl      Reg         Lvl    AllPub    Inside
# freq       1151   1454    50      925        1311      1459      1052
#
#        LandSlope Neighborhood Condition1  ... GarageType GarageFinish  \
# count       1460         1460       1460  ...       1379         1379
# unique         3           25          9  ...          6            3
# top          Gtl        NAmes       Norm  ...     Attchd          Unf
# freq        1382          225       1260  ...        870          605
#
#        GarageQual GarageCond PavedDrive PoolQC  Fence MiscFeature SaleType  \
# count        1379       1379       1460      7    281          54     1460
# unique          5          5          3      3      4           4        9
# ...

# %% [markdown]
# من الواضح من التوزيعات ان توجد انحرافات وقيم متطرفه سواء في البيانات الرقميه او الفؤيه

# %% [markdown]
# # 3- Data Cleaning (Wrangling and Preprocessing )

# %% [markdown]
# اولا التعامل مع القيم الفارغة ايما ان خذفها او ملئها بالقيم سواء الوسيط او المناول في القيم النوعيه او نزيل اعمود نفسه ولكن حفاظان علي قيم البيانات سوف نختار ان تملائها بقيم الوسيط او المنوال

# %%
# Select columns with 'object' data type
object_columns = train_df.select_dtypes(include='object')
# Select columns with numeric data type
num_columns = train_df.select_dtypes(include=['float64', 'int64'])

# Check for missing values in the selected columns
object_null_values = object_columns.isnull().sum()
# Check for missing values in the selected numeric columns
num_null_values = num_columns.isnull().sum()

# Display the columns with missing values
print(object_null_values[object_null_values > 0])
print(20*"*")
# Display the columns with missing values
print(num_null_values[num_null_values > 0])
#null=train_df.isnull().sum()
#null[null>0]
# Out:
# Alley           1369
# MasVnrType       872
# BsmtQual          37
# BsmtCond          37
# BsmtExposure      38
# BsmtFinType1      37
# BsmtFinType2      38
# Electrical         1
# FireplaceQu      690
# GarageType        81
# GarageFinish      81
# GarageQual        81
# GarageCond        81
# PoolQC          1453
# Fence           1179
# MiscFeature     1406
# dtype: int64
# ********************
# LotFrontage    259
# MasVnrArea       8
# GarageYrBlt     81
# dtype: int64

# %%
print('The Dataset contains', train_df.isna().sum().sum(), 
      'missing values and', train_df.duplicated().sum().sum(), 'duplicated values')
# Out:
# The Dataset contains 7829 missing values and 0 duplicated values

# %%
class DataPreprocessor:
    def __init__(self, dataframe):
        self.df = dataframe

    def fillna_with_median(self, column_name):
        median_value = self.df[column_name].median()
        self.df[column_name].fillna(median_value, inplace=True)

    def fillna_with_mode(self, column_name):
        mode_value = self.df[column_name].mode().iloc[0]
        self.df[column_name].fillna(mode_value, inplace=True)
        
preprocessor = DataPreprocessor(train_df)

## The numeric data type

# Replace the empty values in the LoanAmount column with the most median (or mean) value
preprocessor.fillna_with_median("LotFrontage")
# Replace the empty values in the CoapplicantIncome column with the most median (or mean) value
preprocessor.fillna_with_median("MasVnrArea")
# Replace the empty values in the Loan_Amount_Term column with the most median (or mean) value
preprocessor.fillna_with_median("GarageYrBlt")
# Replace the empty values in the Loan_Amount_Term column with the most median (or mean) value
preprocessor.fillna_with_median("SalePrice")



## The Catigrical  data type
 
# Replace the empty values in the Dependents column with the most frequent value
preprocessor.fillna_with_mode("MasVnrType")
# Replace the empty values in the Self_Employed column with the most frequent value
preprocessor.fillna_with_mode("Alley")
# Replace the empty values in the Dependents column with the most frequent value
preprocessor.fillna_with_mode("FireplaceQu")
# Replace the empty values in the Self_Employed column with the most frequent value
preprocessor.fillna_with_mode("Electrical")

# Replace the empty values in the Married column with the most frequent value
preprocessor.fillna_with_mode("BsmtQual")
# Replace the empty values in the Gender column with the most frequent value
preprocessor.fillna_with_mode("BsmtFinType2")
# Replace the empty values in the Married column with the most frequent value
preprocessor.fillna_with_mode("BsmtCond")
# Replace the empty values in the Dependents column with the most frequent value
preprocessor.fillna_with_mode("BsmtFinType1")
# Replace the empty values in the Self_Employed column with the most frequent value
preprocessor.fillna_with_mode("BsmtExposure")

# Replace the empty values in the Gender column with the most frequent value
preprocessor.fillna_with_mode("GarageCond")
# Replace the empty values in the Gender column with the most frequent value
preprocessor.fillna_with_mode("GarageFinish")
# Replace the empty values in the Married column with the most frequent value
preprocessor.fillna_with_mode("GarageType")
# Replace the empty values in the Self_Employed column with the most frequent value
preprocessor.fillna_with_mode("GarageQual")

# Replace the empty values in the Gender column with the most frequent value
preprocessor.fillna_with_mode("Fence")
# Replace the empty values in the Married column with the most frequent value
preprocessor.fillna_with_mode("PoolQC")
# Replace the empty values in the Self_Employed column with the most frequent value
preprocessor.fillna_with_mode("MiscFeature")
      
    
#combined_data.dropna(subset=["SalePrice"])    
# Just Make Sure 
null=train_df.isnull().sum()
print(null[null>0])
print('The Dataset contains', train_df.isna().sum().sum(), 
      'missing values and', train_df.duplicated().sum().sum(), 'duplicated values')
# Out:
# Series([], dtype: int64)
# The Dataset contains 0 missing values and 0 duplicated values

# %% [markdown]
#  نجحنا في عمليه ملئ القيم الفارغة في البيانات بعنايه واستخدمه طريقه يدويه اخدت وقت ولكن اكثر دقه وتاكدنا ان لاتوجد تكرارت مذعجة  (ولكن نعمل بالفعل لاجاد تقنيه اكثر ذكاءا واسرع خصوصا اذا تعاملنا مع بيانات اكبر )

# %% [markdown]
# ولكن هذه ليس هي العلمليه الوحيدة لتنظيف ومعالجة البيانات هناك مهمات اخري مثل (1- تصحيح الاخطاء الاملائيه /2- التعلمل مع الكلمات التي غير مرغوب بها /3- مراغه تناغم وتنسيق البيانات /4- البحث عن القيم النادرة والتعامل معها بشكل منفرد/5-التعامل مع القيم النتطرفة والضوضاء )

# %% [markdown]
# # Numircal Data Visual

# %% [markdown]
# # Catigrical Data Visual

# %% [markdown]
# # Time Series

# %% [markdown]
# # 4- Feature Engineering & preparing to training Model

# %% [markdown]
# ## -- C-Dimensionality Reduction

# %% [markdown]
# ## -- D- Log Trans

# %% [markdown]
# ##   -- E- preparing to training Model

# %%
from sklearn.preprocessing import LabelEncoder
la=LabelEncoder()
train_df.MasVnrTyper=la.fit_transform(train_df.MasVnrType)
train_df.Alley=la.fit_transform(train_df.Alley)
train_df.FireplaceQu=la.fit_transform(train_df.FireplaceQu)
train_df.Electrical=la.fit_transform(train_df.Electrical)
train_df.BsmtQual=la.fit_transform(train_df.BsmtQual)
train_df.BsmtFinType2=la.fit_transform(train_df.BsmtFinType2)
train_df.BsmtCond=la.fit_transform(train_df.BsmtCond)

train_df.BsmtFinType1=la.fit_transform(train_df.BsmtFinType1)
train_df.BsmtExposure=la.fit_transform(train_df.BsmtExposure)
train_df.GarageCond=la.fit_transform(train_df.GarageCond)
train_df.GarageFinish=la.fit_transform(train_df.GarageFinish)
train_df.GarageType=la.fit_transform(train_df.GarageType)
train_df.GarageQual=la.fit_transform(train_df.GarageQual)
train_df.Fence=la.fit_transform(train_df.Fence)
train_df.PoolQC=la.fit_transform(train_df.PoolQC)
train_df.MiscFeature=la.fit_transform(train_df.MiscFeature)

train_df.MSZoning=la.fit_transform(train_df.MSZoning)
train_df.Street=la.fit_transform(train_df.Street)
train_df.LotShape=la.fit_transform(train_df.LotShape)
train_df.SaleType=la.fit_transform(train_df.SaleType)
train_df.SaleCondition=la.fit_transform(train_df.SaleCondition)
train_df.Utilities=la.fit_transform(train_df.Utilities)
train_df.LandContour=la.fit_transform(train_df.LandContour)




train_df.LotConfig=la.fit_transform(train_df.LotConfig)
train_df.LandSlope=la.fit_transform(train_df.LandSlope)
train_df.Neighborhood=la.fit_transform(train_df.Neighborhood)
train_df.Condition1=la.fit_transform(train_df.Condition1)
train_df.Condition2=la.fit_transform(train_df.Condition2)
train_df.BldgType=la.fit_transform(train_df.BldgType)
train_df.HouseStyle=la.fit_transform(train_df.HouseStyle)

train_df.RoofStyle=la.fit_transform(train_df.RoofStyle)
train_df.RoofMatl=la.fit_transform(train_df.RoofMatl)
train_df.Exterior1st=la.fit_transform(train_df.Exterior1st)
train_df.MasVnrType=la.fit_transform(train_df.MasVnrType)
train_df.ExterQual=la.fit_transform(train_df.ExterQual)
train_df.ExterCond=la.fit_transform(train_df.ExterCond)
train_df.Foundation=la.fit_transform(train_df.Foundation)

train_df.Heating=la.fit_transform(train_df.Heating)
train_df.HeatingQC=la.fit_transform(train_df.HeatingQC)
train_df.CentralAir=la.fit_transform(train_df.CentralAir)
train_df.KitchenQual=la.fit_transform(train_df.KitchenQual)
train_df.Functional=la.fit_transform(train_df.Functional)
train_df.PavedDrive=la.fit_transform(train_df.PavedDrive)
train_df.Exterior2nd=la.fit_transform(train_df.Exterior2nd)
#train_df

# %% [markdown]
# ## --- A-Corrolation Data Feature Selection

# %%
train_df_without_ID=train_df.drop(['Id'],axis=1)
correlation = train_df_without_ID.corr()  # Calculate correlations

# Sort features by correlation with 'Exited'
sorted_correlation = correlation[['SalePrice']].sort_values(by='SalePrice', ascending=False)

# Create the heatmap
#plt.figure(figsize=(10, 20))
#heatmap = sns.heatmap(sorted_correlation, vmin=-1, vmax=1, annot=True, cmap='Blues', annot_kws={"fontsize": 12})
#
## Set title and padding
#heatmap.set_title('Features Correlating with Loan_Status', fontdict={'fontsize': 18}, pad=16)
#
## Display the heatmap
#plt.show()
sorted_correlation.head(40)
# Out:
#                SalePrice
# SalePrice       1.000000
# OverallQual     0.790982
# GrLivArea       0.708624
# GarageCars      0.640409
# GarageArea      0.623431
# TotalBsmtSF     0.613581
# 1stFlrSF        0.605852
# FullBath        0.560664
# TotRmsAbvGrd    0.533723
# YearBuilt       0.522897
# YearRemodAdd    0.507101
# MasVnrArea      0.472614
# Fireplaces      0.466929
# GarageYrBlt     0.466754
# BsmtFinSF1      0.386420
# Foundation      0.382479
# LotFrontage     0.334771
# WoodDeckSF      0.324413
# MasVnrType      0.322979
# 2ndFlrSF        0.319334
# OpenPorchSF     0.315856
# HalfBath        0.284108
# LotArea         0.263843
# CentralAir      0.251328
# Electrical      0.234945
# PavedDrive      0.231357
# BsmtFullBath    0.227122
# RoofStyle       0.222405
# BsmtUnfSF       0.214479
# SaleCondition   0.213092
# Neighborhood    0.210851
# HouseStyle      0.180163
# BedroomAbvGr    0.168213
# GarageCond      0.134740
# RoofMatl        0.132383
# ExterCond       0.117303
# ...

# %%
#from sklearn.feature_selection import chi2, SelectKBest, RFE
#from sklearn.svm import LinearSVC
#
#class FeatureSelector:
#    def __init__(self, data, target_column):
#        self.data = data.drop(target_column, axis=1)
#        self.target = data[target_column]
#
#    def chi_squared_selection(self, alpha=0.05):
#        chi2_scores = chi2(self.data, self.target)
#        p_values = chi2_scores[1]
#        sorted_features = np.argsort(p_values)
#        selected_features = [self.data.columns[i] for i in sorted_features if p_values[i] < alpha]
#        return selected_features
#
#    def correlation_coefficient_selection(self, k=10):
#        selector = SelectKBest(k=k)
#        selector.fit(self.data, self.target)
#        selected_features = [self.data.columns[i] for i in selector.get_support(indices=True)]
#        return selected_features
#
#    def recursive_feature_elimination_selection(self, n_features_to_select=5):
#        estimator = LinearSVC()
#        selector = RFE(estimator, n_features_to_select=n_features_to_select)
#        selector.fit(self.data, self.target)
#        selected_features_indices = selector.support_
#        selected_features = self.data.columns[selected_features_indices]
#        return selected_features
#
## Example Usage:
#loan_status_column = 'SalePrice'
#
#feature_selector = FeatureSelector(train_df_without_ID, loan_status_column)
#
## Method 1: Chi-squared test
#selected_features_chi2 = feature_selector.chi_squared_selection()
#print("Chi-squared selected features:", selected_features_chi2)
#print ("\n")
## Method 2: Correlation coefficients
#selected_features_corr = feature_selector.correlation_coefficient_selection()
#print("Correlation coefficients selected features:", selected_features_corr)
#print ("\n")
## Method 3: Recursive Feature Elimination (RFE)
#selected_features_rfe = feature_selector.recursive_feature_elimination_selection()
#print("RFE selected features:", selected_features_rfe)
#print ("\n")
#K = 10
#cols = correlation.nlargest(K, 'SalePrice')['SalePrice'].index
#print ('correlation.nlargest : ',cols)

# %% [markdown]
# ## --- B- Normlization (Feature Scaling) & Standerlization

# %% [markdown]
# ### Filtering using Variance Threshold (After)

# %%
# Calculate variance for each column
variances = train_df_without_ID.var()

# Print the variances
print(variances)
# Out:
# MSSubClass       1.789338e+03
# MSZoning         3.994460e-01
# LotFrontage      4.852186e+02
# LotArea          9.962565e+07
# Street           4.095505e-03
#                      ...
# MoSold           7.309595e+00
# YrSold           1.763837e+00
# SaleType         2.409015e+00
# SaleCondition    1.211880e+00
# SalePrice        6.311111e+09
# Length: 80, dtype: float64

# %%
#from sklearn.preprocessing import StandardScaler, MinMaxScaler
#
#class DataProcessor:
#    def __init__(self, data):
#        self.data = data
#
#    def standardize_data(self, columns_to_standardize):
#        scaler = StandardScaler()
#        self.data[columns_to_standardize] = scaler.fit_transform(self.data[columns_to_standardize])
#        return self.data
#
#    def normalize_data(self, columns_to_normalize):
#        scaler = MinMaxScaler()
#        self.data[columns_to_normalize] = scaler.fit_transform(self.data[columns_to_normalize])
#        return self.data
#
## Example Usage:
## Assuming you have a DataFrame called 'df' with columns to be standardized and normalized
## You can replace this with your actual DataFrame and columns
#
## Create an instance of DataProcessor
#data_processor = DataProcessor(data_4)
#
## Method 1: Standardization
#columns_to_standardize = ['LoanAmount', 'Loan_Amount_Term']  # Replace with actual column names
#df_standardized = data_processor.standardize_data(columns_to_standardize)
##print("Standardized Data:")
##print(df_standardized.sum())
#
## Method 2: Normalization
#columns_to_normalize = ['Property_Area','CoapplicantIncome']  # Replace with actual column names
#df_normalized = data_processor.normalize_data(columns_to_normalize)
##print("\nNormalized Data:")
##df_normalized.sum()
#

# %% [markdown]
# ### Filtering using Variance Threshold (Before)

# %%
# Calculate variance for each column
variances = train_df_without_ID.var()

# Print the variances
print(variances)
# Out:
# MSSubClass       1.789338e+03
# MSZoning         3.994460e-01
# LotFrontage      4.852186e+02
# LotArea          9.962565e+07
# Street           4.095505e-03
#                      ...
# MoSold           7.309595e+00
# YrSold           1.763837e+00
# SaleType         2.409015e+00
# SaleCondition    1.211880e+00
# SalePrice        6.311111e+09
# Length: 80, dtype: float64

# %% [markdown]
# # 5- Creat The Model Testing

# %% [markdown]
# ## --A- perparing The Traning And Testing part

# %%
X_train = train_df.drop("SalePrice", axis=1)
y_train = train_df["SalePrice"]
X_test  = test_df.drop("Id", axis=1).copy()

from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
# Previous code...
X_train, X_test, y_train, y_test = train_test_split(X_train, y_train, test_size=0.1, random_state=40, shuffle=True)
X_train.shape, y_train.shape, X_test.shape
# Out:
# ((1314, 80), (1314,), (146, 80))

# %% [markdown]
# # LinearRegression

# %%
# Create a linear regression model
Linear_Regression = LinearRegression()

# Train the model
Linear_Regression.fit(X_train, y_train)

# Make predictions on the test set
Y_pred = Linear_Regression.predict(X_test)

# Calculate Mean Squared Error (MSE) and Root Mean Squared Error (RMSE)
RMSE = np.sqrt(mean_squared_error(y_test, Y_pred))
print(f'RMSE is: {RMSE:.2f}')

mse = mean_squared_error(y_test, Y_pred)
print(f'Mean Squared Error: {mse:.2f}')

# Calculate R-squared (R2) score
r2 = r2_score(y_test, Y_pred)
print(f'R-squared (R2) Score: {r2:.2f}')

# Sort the values for smoother line in the plot
sort_indices = np.argsort(X_test.iloc[:, 0])
X_test_sorted = X_test.iloc[sort_indices]

# Sort the corresponding predictions
Y_pred_sorted = Y_pred[sort_indices]

# Plot the original data and the linear regression line
plt.figure(figsize=(15, 6), dpi=200)
plt.scatter(X_test.iloc[:, 0], y_test, color='black', label='Actual Data')
plt.plot(X_test_sorted.iloc[:, 0], Y_pred_sorted, color='blue', linewidth=3, label='Linear Regression Line')
plt.xlabel('X-axis Label')
plt.ylabel('Y-axis Label')
plt.title('Linear Regression Prediction')
plt.legend()
plt.show()
# Out:
# RMSE is: 27852.90
# Mean Squared Error: 775784055.24
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 18
#      15 print(f'Mean Squared Error: {mse:.2f}')
#      17 # Calculate R-squared (R2) score
# ---> 18 r2 = r2_score(y_test, Y_pred)
#      19 print(f'R-squared (R2) Score: {r2:.2f}')
#      21 # Sort the values for smoother line in the plot
#
# NameError: name 'r2_score' is not defined

# %%
import numpy as np

def gradient_descent(X, y, learning_rate=0.01, num_iterations=1000):
    m, n = X.shape  # Number of training examples (m) and features (n)
    theta = np.zeros((n, 1))  # Initialize parameters

    for _ in range(num_iterations):
        for i in range(m):
            xi = X[i, :].reshape((1, n))
            yi = y[i]

            # Compute the gradient for each example
            gradient = xi.T.dot(xi.dot(theta) - yi)

            # Update parameters
            theta = theta - learning_rate * gradient

    return theta

# Example usage:
# X_train is your feature matrix, y_train is your target vector
# Make sure to normalize/standardize features and add bias term if needed
# X_train = ...
# y_train = ...
# X_train = np.c_[np.ones((X_train.shape[0], 1)), X_train]  # Add bias term

# Set hyperparameters
learning_rate = 0.01
num_iterations = 1000

# Run gradient descent
theta = gradient_descent(X_train, y_train, learning_rate, num_iterations)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3653, in Index.get_loc(self, key)
#    3652 try:
# -> 3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:153, in pandas._libs.index.IndexEngine.get_loc()
#
# TypeError: '(0, slice(None, None, None))' is an invalid key
#
# During handling of the above exception, another exception occurred:
#
# InvalidIndexError                         Traceback (most recent call last)
# Cell In[21], line 32
#      29 num_iterations = 1000
#      31 # Run gradient descent
# ...

# %%
# Import necessary libraries
from sklearn.svm import SVR
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

# Create a Support Vector Regression (SVR) model
svr = SVR()

# Train the model
svr.fit(X_train, y_train)

# Make predictions on the test set
Y_pred = svr.predict(X_test)

# Calculate Mean Squared Error (MSE) and Root Mean Squared Error (RMSE)
mse = mean_squared_error(y_test, Y_pred)
rmse = np.sqrt(mse)
# Calculate R-squared (R2) score
r2 = r2_score(y_test, Y_pred)
print(f'R-squared (R2) Score: {r2:.2f}')

print(f'Mean Squared Error (MSE): {mse:.2f}')
print(f'Root Mean Squared Error (RMSE): {rmse:.2f}')

# Plot the original data and the SVR predictions
plt.figure(figsize=(15, 6), dpi=200)
plt.scatter(X_test.iloc[:, 0], y_test, color='black', label='Actual Data')
plt.plot(X_test.iloc[:, 0], Y_pred, color='blue', linewidth=3, label='SVR Predictions')
plt.xlabel('X-axis Label')
plt.ylabel('Y-axis Label')
plt.title('SVR Prediction')
plt.legend()
plt.show()

# %%
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
import numpy as np
import matplotlib.pyplot as plt

# Assuming X_train and y_train are already defined

# Create a PolynomialFeatures object
poly = PolynomialFeatures(degree=2, include_bias=False)

# Transform the input data
X_train_poly = poly.fit_transform(X_train)
X_test_poly = poly.transform(X_test)

# Create a Linear Regression model
linear_regression_model = LinearRegression()

# Train the model
linear_regression_model.fit(X_train_poly, y_train)

# Make predictions on the test set
Y_pred = linear_regression_model.predict(X_test_poly)

# Calculate Mean Squared Error (MSE) and Root Mean Squared Error (RMSE)
mse = mean_squared_error(y_test, Y_pred)
rmse = np.sqrt(mse)

print(f'Mean Squared Error (MSE): {mse:.2f}')
print(f'Root Mean Squared Error (RMSE): {rmse:.2f}')

# Plot the original data and the Polynomial Regression predictions
plt.figure(figsize=(15, 6), dpi=200)
plt.scatter(X_test.iloc[:, 0], y_test, color='black', label='Actual Data')
plt.plot(X_test.iloc[:, 0], Y_pred, color='blue', linewidth=3, label='Polynomial Regression Predictions')
plt.xlabel('X-axis Label')
plt.ylabel('Y-axis Label')
plt.title('Polynomial Regression Prediction')
plt.legend()
plt.show()

# %%
# Import necessary libraries
from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
import matplotlib.pyplot as plt
import numpy as np

# Assuming you have X_train, X_test, y_train, and y_test from your data
# If not, you need to split your data into training and testing sets

# Create a Decision Tree Regressor model
dt_regressor = DecisionTreeRegressor()

# Train the model
dt_regressor.fit(X_train, y_train)

# Make predictions on the test set
y_pred = dt_regressor.predict(X_test)

# Calculate Mean Squared Error (MSE) and Root Mean Squared Error (RMSE)
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)

print(f'Mean Squared Error (MSE): {mse:.2f}')
print(f'Root Mean Squared Error (RMSE): {rmse:.2f}')

# Plot the original data and the Decision Tree predictions
plt.figure(figsize=(15, 6), dpi=200)
plt.scatter(X_test.iloc[:, 0], y_test, color='black', label='Actual Data')
plt.scatter(X_test.iloc[:, 0], y_pred, color='red', label='Decision Tree Predictions')
plt.xlabel('X-axis Label')
plt.ylabel('Y-axis Label')
plt.title('Decision Tree Regressor Prediction')
plt.legend()
plt.show()

# %%
# Import necessary libraries
from sklearn.linear_model import Lasso
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
import matplotlib.pyplot as plt
import numpy as np

# Assuming you have X_train, X_test, y_train, and y_test from your data
# If not, you need to split your data into training and testing sets

# Create a Lasso regression model
lasso_reg = Lasso(alpha=0.01)  # You can adjust the alpha parameter based on your needs

# Train the model
lasso_reg.fit(X_train, y_train)

# Make predictions on the test set
y_pred = lasso_reg.predict(X_test)

# Calculate Mean Squared Error (MSE) and Root Mean Squared Error (RMSE)
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)

print(f'Mean Squared Error (MSE): {mse:.2f}')
print(f'Root Mean Squared Error (RMSE): {rmse:.2f}')

# Plot the original data and the Lasso regression predictions
plt.figure(figsize=(15, 6), dpi=200)
plt.scatter(X_test.iloc[:, 0], y_test, color='black', label='Actual Data')
plt.scatter(X_test.iloc[:, 0], y_pred, color='green', label='Lasso Regression Predictions')
plt.xlabel('X-axis Label')
plt.ylabel('Y-axis Label')
plt.title('Lasso Regression Prediction')
plt.legend()
plt.show()

# %% [markdown]
# # -- B- Ensemple Learning

# %%
# Import necessary libraries
from sklearn.ensemble import BaggingRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
import matplotlib.pyplot as plt
import numpy as np

# Assuming you have X_train, X_test, y_train, and y_test from your data
# If not, you need to split your data into training and testing sets

# Create a base regression model (you can replace this with any regression model)
base_model = BaggingRegressor()  # Replace YourBaseRegressionModel with the desired model

# Create a BaggingRegressor
bagging_reg = BaggingRegressor(base_model, n_estimators=10, random_state=42)  # You can adjust the number of estimators

# Train the model
bagging_reg.fit(X_train, y_train)

# Make predictions on the test set
y_pred = bagging_reg.predict(X_test)

# Calculate Mean Squared Error (MSE) and Root Mean Squared Error (RMSE)
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)

print(f'Mean Squared Error (MSE): {mse:.2f}')
print(f'Root Mean Squared Error (RMSE): {rmse:.2f}')

# Plot the original data and the BaggingRegressor predictions
plt.figure(figsize=(15, 6), dpi=200)
plt.scatter(X_test.iloc[:, 0], y_test, color='black', label='Actual Data')
plt.scatter(X_test.iloc[:, 0], y_pred, color='orange', label='BaggingRegressor Predictions')
plt.xlabel('X-axis Label')
plt.ylabel('Y-axis Label')
plt.title('BaggingRegressor Prediction')
plt.legend()
plt.show()

# %%
# Import necessary libraries
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
import matplotlib.pyplot as plt
import numpy as np

# Assuming you have X_train, X_test, y_train, and y_test from your data
# If not, you need to split your data into training and testing sets

# Create a RandomForestRegressor
rf_reg = RandomForestRegressor(n_estimators=100, random_state=42)  # You can adjust the number of estimators

# Train the model
rf_reg.fit(X_train, y_train)

# Make predictions on the test set
y_pred = rf_reg.predict(X_test)

# Calculate Mean Squared Error (MSE) and Root Mean Squared Error (RMSE)
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)

print(f'Mean Squared Error (MSE): {mse:.2f}')
print(f'Root Mean Squared Error (RMSE): {rmse:.2f}')

# Plot the original data and the RandomForestRegressor predictions
plt.figure(figsize=(15, 6), dpi=200)
plt.scatter(X_test.iloc[:, 0], y_test, color='black', label='Actual Data')
plt.scatter(X_test.iloc[:, 0], y_pred, color='green', label='RandomForestRegressor Predictions')
plt.xlabel('X-axis Label')
plt.ylabel('Y-axis Label')
plt.title('RandomForestRegressor Prediction')
plt.legend()
plt.show()

# %%
# Import necessary libraries
from sklearn.ensemble import AdaBoostRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
import matplotlib.pyplot as plt
import numpy as np

# Assuming you have X_train, X_test, y_train, and y_test from your data
# If not, you need to split your data into training and testing sets

# Create an AdaBoostRegressor
ada_reg = AdaBoostRegressor(n_estimators=50, random_state=42)  # You can adjust the number of estimators

# Train the model
ada_reg.fit(X_train, y_train)

# Make predictions on the test set
y_pred = ada_reg.predict(X_test)

# Calculate Mean Squared Error (MSE) and Root Mean Squared Error (RMSE)
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)

print(f'Mean Squared Error (MSE): {mse:.2f}')
print(f'Root Mean Squared Error (RMSE): {rmse:.2f}')

# Plot the original data and the AdaBoostRegressor predictions
plt.figure(figsize=(15, 6), dpi=200)
plt.scatter(X_test.iloc[:, 0], y_test, color='black', label='Actual Data')
plt.scatter(X_test.iloc[:, 0], y_pred, color='red', label='AdaBoostRegressor Predictions')
plt.xlabel('X-axis Label')
plt.ylabel('Y-axis Label')
plt.title('AdaBoostRegressor Prediction')
plt.legend()
plt.show()

# %%
# Import necessary libraries
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
import matplotlib.pyplot as plt
import numpy as np

# Assuming you have X_train, X_test, y_train, and y_test from your data
# If not, you need to split your data into training and testing sets

# Create a GradientBoostingRegressor
gb_reg = GradientBoostingRegressor(n_estimators=100, learning_rate=0.1, random_state=42)  
# You can adjust the number of estimators and learning rate based on your requirements

# Train the model
gb_reg.fit(X_train, y_train)

# Make predictions on the test set
y_pred_gb_reg = gb_reg.predict(X_test)

# Calculate Mean Squared Error (MSE) and Root Mean Squared Error (RMSE)
mse = mean_squared_error(y_test, y_pred_gb_reg)
rmse = np.sqrt(mse)

from sklearn.metrics import r2_score
from sklearn import metrics
error_score = metrics.r2_score(y_test,y_pred_gb_reg)
print("R squared(r**2) error : ", error_score)


print(f'Mean Squared Error (MSE): {mse:.2f}')
print(f'Root Mean Squared Error (RMSE): {rmse:.2f}')

# Plot the original data and the GradientBoostingRegressor predictions
plt.figure(figsize=(15, 6), dpi=200)
sns.regplot(data=error_score, x=y_test, y=y_pred_gb_reg, marker="o")
plt.scatter(X_test.iloc[:, 0], y_test, color='black', label='Actual Data')
plt.scatter(X_test.iloc[:, 0], y_pred, color='green', label='GradientBoostingRegressor Predictions')
plt.xlabel('X-axis Label')
plt.ylabel('Y-axis Label')
plt.title('GradientBoostingRegressor Prediction')
plt.legend()
plt.show()

# %%
import seaborn as sns

# Sort the data for plotting the fit line
sort_indices = np.argsort(X_test.iloc[:, 0])
x_sorted = X_test.iloc[:, 0].values[sort_indices]
y_test_sorted = y_test.values[sort_indices]
y_pred_gb_reg_sorted = y_pred_gb_reg[sort_indices]

# Plot the original data and the Gradient Boosting Regressor predictions
plt.figure(figsize=(15, 6), dpi=200)
sns.regplot(data=error_score, x=x_sorted, y=y_test_sorted, marker="o", scatter_kws={'s':10})
plt.scatter(X_test.iloc[:, 0], y_test, color='black', label='Actual Data')
plt.plot(x_sorted, y_pred_gb_reg_sorted, color='green', label='Gradient Boosting Regressor Fit Line')
plt.xlabel('X-axis Label')
plt.ylabel('Y-axis Label')
plt.title('Gradient Boosting Regressor Prediction')
plt.legend()
plt.show()

# %%
# Import necessary libraries
import xgboost as xgb
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
import matplotlib.pyplot as plt
import numpy as np

# Assuming you have X_train, X_test, y_train, and y_test from your data
# If not, you need to split your data into training and testing sets

# Create an XGBoost Regressor
xg_reg = xgb.XGBRegressor(objective ='reg:squarederror', colsample_bytree = 0.3, learning_rate = 0.1,
                max_depth = 5, alpha = 10, n_estimators = 10, random_state=42)

# Train the model
xg_reg.fit(X_train, y_train)

# Make predictions on the test set
y_pred_xg_reg = xg_reg.predict(X_test)

# Calculate Mean Squared Error (MSE) and Root Mean Squared Error (RMSE)
mse = mean_squared_error(y_test, y_pred_xg_reg)
rmse = np.sqrt(mse)

# Calculate R-squared
r2 = metrics.r2_score(y_test, y_pred_xg_reg)
print("R-squared (R^2) error: ", r2)

print(f'Mean Squared Error (MSE): {mse:.2f}')
print(f'Root Mean Squared Error (RMSE): {rmse:.2f}')

# Plot the original data and the XGBoost Regressor predictions
plt.figure(figsize=(15, 6), dpi=200)
plt.scatter(X_test.iloc[:, 0], y_test, color='black', label='Actual Data')
plt.scatter(X_test.iloc[:, 0], y_pred_xg_reg, color='red', label='XGBoost Regressor Predictions')
plt.xlabel('X-axis Label')
plt.ylabel('Y-axis Label')
plt.title('XGBoost Regressor Prediction')
plt.legend()
plt.show()

# %%
import seaborn as sns

# Sort the data for plotting the fit line
sort_indices = np.argsort(X_test.iloc[:, 0])
x_sorted = X_test.iloc[:, 0].values[sort_indices]
y_test_sorted = y_test.values[sort_indices]
y_pred_gb_reg_sorted = y_pred_gb_reg[sort_indices]

# Plot the original data and the Gradient Boosting Regressor predictions
plt.figure(figsize=(15, 6), dpi=200)
sns.regplot(data=error_score, x=x_sorted, y=y_test_sorted, marker="o", scatter_kws={'s':10})
plt.scatter(X_test.iloc[:, 0], y_test, color='black', label='Actual Data')
plt.plot(x_sorted, y_pred_gb_reg_sorted, color='green', label='Gradient Boosting Regressor Fit Line')
plt.xlabel('X-axis Label')
plt.ylabel('Y-axis Label')
plt.title('Gradient Boosting Regressor Prediction')
plt.legend()
plt.show()

# %% [markdown]
# ## Voting & Stacking

# %%
from sklearn.ensemble import RandomForestRegressor
RandomForestRegressormodel = RandomForestRegressor(n_estimators=100, max_depth=10, min_samples_split=2, min_samples_leaf=1)
RandomForestRegressormodel.fit(X_train,y_train)

# Model Evaluation prediction on Test Data
y_pred= RandomForestRegressormodel.predict(X_test)
y_pred[:10]

# %%
from sklearn.metrics import r2_score
from sklearn import metrics
error_score = metrics.r2_score(y_test,y_pred)
print("R squared(r**2) error : ", error_score)

# %%
y_test=list(y_test)
plt.figure(figsize=(12,8))
plt.plot(y_test , color='red', label='Actual Price')
plt.plot(y_pred, color='gold', label='predicted price')
plt.title('Actual price vs Predicted price')
plt.xlabel('Number of values')
plt.ylabel('SalePrice')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(15,6),dpi=200)
sns.regplot(data=error_score, x=y_test, y=y_pred, marker="o")
plt.show();

# %%
# SVR Algorithm
from sklearn.svm import SVR
#SVRmodel = SVR (C=20,kernel="rbf")
SVRmodel = SVR (C=20,kernel="linear")
SVRmodel.fit(X_train,y_train)

ySVR_pred= SVRmodel.predict(X_test)
print("Prediction:",ySVR_pred[:10])
print ("***********************************************************************")
from sklearn.metrics import r2_score
from sklearn import metrics
error_score = metrics.r2_score(y_test,ySVR_pred)
print("R squared(r**2) error : ", error_score)

plt.figure(figsize=(15,6),dpi=200)
sns.regplot(data=error_score, x=y_test, y=ySVR_pred, marker="o")
plt.show();

# %%
#DecisionTree Regrassion Algorithm
from sklearn.tree import DecisionTreeRegressor
DecisionTreeRegressormodel =DecisionTreeRegressor(max_depth=20)
DecisionTreeRegressormodel.fit(X_train,y_train)

yDTR_pred= DecisionTreeRegressormodel.predict(X_test)
print("prediction :",yDTR_pred[:10])
print ("**************************************************************")
from sklearn.metrics import r2_score
from sklearn import metrics
error_score = metrics.r2_score(y_test,yDTR_pred)
print("R squared(r**2) error : ", error_score)

plt.figure(figsize=(15,6),dpi=200)
sns.regplot(data=error_score, x=y_test, y=yDTR_pred, marker="o")
plt.show();

# %%
# GradientBoostingRegrassor Algorithm
from sklearn.ensemble import GradientBoostingRegressor
GradientBoostingRegressormodel =GradientBoostingRegressor()
GradientBoostingRegressormodel.fit(X_train,y_train)

yGBR_pred= GradientBoostingRegressormodel.predict(X_test)
print("prediction :",yGBR_pred[:10])
print ("**************************************************************")
from sklearn.metrics import r2_score
from sklearn import metrics
error_score = metrics.r2_score(y_test,yGBR_pred)
print("R squared(r**2) error : ", error_score)

plt.figure(figsize=(15,6),dpi=200)
sns.regplot(data=error_score, x=y_test, y=yGBR_pred, marker="o")
plt.show();

# %%
#LinearRegression Algorithm
from sklearn.linear_model import LinearRegression
LinearRegressionmodel =LinearRegression()
LinearRegressionmodel.fit(X_train,y_train)

yLR_pred= LinearRegressionmodel.predict(X_test)
print("prediction :",yLR_pred[:10])
print ("**************************************************************")
from sklearn.metrics import r2_score
from sklearn import metrics
error_score = metrics.r2_score(y_test,yLR_pred)
print("R squared(r**2) error : ", error_score)

plt.figure(figsize=(15,6),dpi=200)
sns.regplot(data=error_score, x=y_test, y=yLR_pred, marker="o")
plt.show();

# %% [markdown]
# # 6- Data Evaluation

# %% [markdown]
# # 7- Summary  (Results, suggestions and recommendations)
